# %%
# import libraries
import numpy as np
import sympy as sym

# make the equations look nicer
from IPython.display import display

# %%
# Create symbolic variables in sympy
x = sym.symbols('x')

# Create two functions
f_x = 2 * x ** 2
g_x = 4 * x ** 3 - 3 * x ** 4

# Compute their individual derivatives
d_f = sym.diff(f_x)
d_g = sym.diff(g_x)

# Apply the product rule "manually"
manual = d_f * g_x + f_x * d_g
the_wrong_way = d_f * d_g

# Via sympy
via_sympy = sym.diff(f_x * g_x)

# Print everything
print('The functions:')
display(f_x)
display(g_x)
print(' ')

print('Their derivatives:')
display(d_f)
display(d_g)
print(' ')

print('Manual product rule:')
display(manual)
print(' ')

print('Via sympy:')
display(via_sympy)
print(' ')

print('The wrong way:')
display(the_wrong_way)
# Out:
# The functions:
# 2*x**2
# -3*x**4 + 4*x**3
#
# Their derivatives:
# 4*x
# -12*x**3 + 12*x**2
#
# Manual product rule:
# 2*x**2*(-12*x**3 + 12*x**2) + 4*x*(-3*x**4 + 4*x**3)
#
# Via sympy:
# 2*x**2*(-12*x**3 + 12*x**2) + 4*x*(-3*x**4 + 4*x**3)
#
# The wrong way:
# 4*x*(-12*x**3 + 12*x**2)

# %%
# Repeat with chain rule
g_x = x ** 2 + 4 * x ** 3
f_x = g_x ** 5

print('The function:')
display(f_x)
print(' ')

print('Its derivative:')
display(sym.diff(f_x))
# Out:
# The function:
# (4*x**3 + x**2)**5
#
# Its derivative:
# (60*x**2 + 10*x)*(4*x**3 + x**2)**4
