# %%
# Import libraries
import numpy as np
import matplotlib.pyplot as plt

# %%
# Create a list of numbers to compute the mean and variance of
x = [1, 2, 4, 6, 5, 4, 0, -4, 5, -2, 6, 10, -9, 1, 3, -6]
n = len(x)

# Compute the population mean
pop_mean = np.mean(x)

# Compute a sample mean
# Select random sample (05)
sample      = np.random.choice(a=x, size=5, replace=True)
sample_mean = np.mean(sample)

# Print them
print(pop_mean)
print(sample_mean)
# Out:
# 1.625
# 3.8

# %%
# Compute lots of sample means

# Number of experiments to run
nExpers = 10000

# Run the experiment!
sampleMeans = np.zeros(nExpers)

for i in range(nExpers):
  # Step 1: draw a sample
  sample = np.random.choice(x, size=15, replace=True)

  # Step 2: compute its mean and store
  sampleMeans[i] = np.mean(sample)

# Show the results as a histogram
plt.hist(sampleMeans, bins=40, density=True)
plt.plot([pop_mean, pop_mean], [0, 0.3], 'm--')
plt.ylabel('Count')
plt.xlabel('Sample Mean')
plt.show()
